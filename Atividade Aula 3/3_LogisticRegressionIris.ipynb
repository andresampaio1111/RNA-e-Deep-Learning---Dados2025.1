# %% [markdown]
# # Iris dataset - Regressão Logística - 3 classes

# %% [markdown]
# ## Objetivos

# %% [markdown]
# Este notebook ilustra o problema de classificação.
#
# O objetivo é classificar as amostras da Íris em 3 classes.
# - o alvo é o índice da classe: 0, 1 ou 2
# - função de perda é Entropia Cruzada
# - rede é uma camada densa linear com duas entradas e três saídas (n. de classes)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoSoftmax_CrossEntropy_Otimizacao.png)

# %% [markdown]
# ## Importação das bibliotecas

# %%
# %matplotlib inline
import os
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

from IPython import display
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Dataset: Leitura, normalização e visualização dos dados

# %%
iris = load_iris()
X = iris.data[:,::2]  # comprimento das sépalas e pétalas, indices 0 e 2
# normalização
Xc = X - X.min(axis=0)
Xs = Xc.max(axis=0)
Xc = Xc/Xs

Y = iris.target
colors = np.array(['r','y','b'])
plt.scatter(Xc[:, 0], Xc[:, 1], c=colors[Y])
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.show()

# %% [markdown]
# # Dividindo Dataset em Treinamento E Validação

# %%
x_train, x_test, y_train, y_test = train_test_split(Xc, Y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 2)
# (30, 2)
# (120,)
# (30,)

# %% [markdown]
# ### Prepara os dados para o PyTorch

# %%
X_train_tensor = torch.FloatTensor(x_train)  # Entrada é FloatTensor
Y_train_tensor = torch.LongTensor(y_train)    # Classe é LongTensor
X_test_tensor = torch.FloatTensor(x_test)  # Entrada é FloatTensor
Y_test_tensor = torch.LongTensor(y_test)    # Classe é LongTensor

# %%
Y_train_tensor
# Out:
# tensor([0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 2, 1, 2, 1, 0,
#         2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0, 1, 2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1,
#         0, 1, 2, 0, 0, 1, 1, 0, 2, 0, 0, 1, 1, 2, 1, 2, 2, 1, 0, 0, 2, 2, 0, 0,
#         0, 1, 2, 0, 2, 2, 0, 1, 1, 2, 1, 2, 0, 2, 1, 2, 1, 1, 1, 0, 1, 1, 0, 1,
#         2, 2, 0, 1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2, 1, 1, 2, 2, 0, 1, 2, 0, 1, 2])

# %%
X_train_tensor
# Out:
# tensor([[0.0833, 0.0000],
#         [0.3889, 0.0847],
#         [0.6667, 0.5763],
#         [0.1389, 0.1017],
#         [0.0278, 0.0508],
#         [0.5556, 0.6780],
#         [0.5833, 0.5932],
#         [0.2500, 0.0847],
#         [0.1944, 0.0678],
#         [0.2500, 0.0847],
#         [0.4167, 0.6949],
#         [0.4722, 0.5932],
#         [0.6667, 0.6271],
#         [0.3056, 0.0508],
#         [0.3056, 0.0847],
#         [0.3333, 0.4576],
#         [0.5556, 0.6949],
#         [0.5833, 0.7627],
#         [0.6389, 0.5763],
#         [0.8056, 0.8644],
#         [0.3889, 0.5424],
#         [0.9167, 0.9492],
#         [0.3611, 0.5932],
#         [0.2222, 0.0678],
#         [0.9444, 0.9661],
#         [0.4167, 0.5254],
#         [0.2500, 0.0678],
#         [0.1944, 0.0508],
#         [0.2222, 0.1525],
#         [0.1944, 0.4237],
#         [0.5556, 0.6610],
#         [0.1389, 0.1525],
#         [0.1944, 0.1017],
#         [0.2222, 0.1186],
#         [0.3611, 0.5424],
#         [0.2222, 0.0847],
#         [0.3889, 0.5424],
#         [0.9444, 0.9661],
#         [0.0833, 0.0678],
#         [0.5278, 0.5593],
#         [0.3889, 0.6780],
#         [0.3333, 0.0678],
#         [0.4722, 0.6441],
#         [0.4167, 0.6949],
#         [0.4722, 0.5085],
#         [0.3056, 0.5932],
#         [0.5278, 0.7458],
#         [0.3333, 0.5085],
#         [0.3056, 0.1186],
#         [0.1944, 0.3898],
#         [0.5833, 0.7288],
#         [0.1944, 0.0678],
#         [0.1944, 0.0339],
#         [0.3333, 0.4746],
#         [0.6667, 0.6780],
#         [0.1667, 0.0847],
#         [0.4167, 0.6949],
#         [0.1944, 0.0847],
#         [0.1944, 0.1017],
#         [0.4444, 0.6441],
#         [0.2222, 0.3390],
#         [0.7222, 0.7966],
#         [0.4722, 0.6949],
#         [0.5000, 0.7797],
#         [0.9444, 0.8644],
#         [0.3333, 0.5085],
#         [0.0278, 0.0678],
#         [0.0000, 0.0169],
#         [0.4722, 0.6780],
#         [0.8056, 0.8475],
#         [0.0833, 0.0847],
#         [0.2222, 0.0678],
#         [0.0278, 0.0508],
#         [0.5556, 0.6610],
#         [0.5556, 0.7797],
#         [0.0833, 0.0678],
#         [0.6944, 0.7627],
#         [0.5556, 0.8475],
#         [0.1111, 0.0508],
#         [0.5000, 0.6271],
#         [0.6111, 0.6102],
#         [0.5278, 0.6441],
#         [0.7500, 0.6271],
#         [0.5833, 0.7288],
#         [0.2222, 0.1017],
#         [0.7222, 0.7458],
#         [0.4444, 0.5424],
#         [0.6111, 0.7119],
#         [0.3889, 0.4237],
#         [0.2500, 0.4915],
#         [0.5000, 0.6102],
#         [0.0556, 0.0508],
#         [0.6389, 0.6102],
#         [0.3333, 0.5763],
#         [0.2778, 0.0847],
#         [0.3611, 0.5254],
#         [0.8333, 0.8983],
#         [0.6667, 0.7966],
#         [0.2222, 0.0847],
#         [0.1667, 0.3898],
#         [0.6667, 0.7966],
#         [0.8056, 0.8136],
#         [0.1667, 0.0678],
#         [0.6667, 0.7797],
#         [0.1667, 0.0678],
#         [0.7222, 0.6610],
#         [0.8611, 0.8644],
#         [0.5556, 0.7797],
#         [0.3889, 0.5254],
#         [0.6111, 0.7627],
#         [0.5556, 0.5763],
#         [0.5833, 0.5593],
#         [0.3611, 0.6610],
#         [0.4444, 0.6949],
#         [0.3056, 0.1186],
#         [0.5000, 0.5085],
#         [0.1667, 0.5932],
#         [0.4167, 0.0339],
#         [0.4167, 0.5085],
#         [0.7778, 0.8305]])

# %% [markdown]
# ## Construindo o modelo da rede

# %% [markdown]
# A saída da rede é composta por um neurônio para cada classe. A saída é denominada *scores* ou logitos:
#
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLogisticaRede_2_3.png)

# %%
model = nn.Linear(2,3)  # 2 entradas e 3 saídas

# %%
model.state_dict()
# Out:
# OrderedDict([('weight',
#               tensor([[-0.2309,  0.3356],
#                       [ 0.0693, -0.3044],
#                       [-0.3945, -0.2608]])),
#              ('bias', tensor([-0.0397, -0.5158, -0.5312]))])

# %% [markdown]
# ### Fazendo um predict

# %%
out = model(X_train_tensor[:4,:]) # 4 amostras
out
# Out:
# tensor([[-5.8934e-02, -5.0998e-01, -5.6406e-01],
#         [-1.0104e-01, -5.1461e-01, -7.0669e-01],
#         [-2.1195e-04, -6.4497e-01, -9.4447e-01],
#         [-3.7631e-02, -5.3708e-01, -6.1250e-01]], grad_fn=<AddmmBackward0>)

# %%
oo = F.softmax(out,dim=1)
oo
# Out:
# tensor([[0.4464, 0.2843, 0.2693],
#         [0.4531, 0.2996, 0.2473],
#         [0.5225, 0.2742, 0.2032],
#         [0.4609, 0.2797, 0.2594]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ### Calculando as probabilidades com Softmax

# %% [markdown]
# - [Wikipedia:Softmax_function](https://en.wikipedia.org/wiki/Softmax_function)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/softmax.png)

# %%
F.softmax(out,dim=1)*100
# Out:
# tensor([[44.6350, 28.4308, 26.9342],
#         [45.3103, 29.9631, 24.7266],
#         [52.2532, 27.4220, 20.3248],
#         [46.0905, 27.9706, 25.9388]], grad_fn=<MulBackward0>)

# %% [markdown]
# ### Predição da classe

# %%
prob,y_pred = torch.max(F.softmax(out,dim=1),dim=1)
print(y_pred)
print(prob)
# Out:
# tensor([0, 0, 0, 0])
# tensor([0.4464, 0.4531, 0.5225, 0.4609], grad_fn=<MaxBackward0>)

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Classe para visualização dinâmica

# %%
def predict(model, inputs):
    outputs = model(Variable(inputs))
    _, predicts = torch.max(outputs, 1)

    return predicts.data.numpy()

def predict_prob(model, inputs):
    outputs = model(Variable(inputs))
    outputs = F.softmax(outputs,dim=1)
    predicts, _ = torch.max(outputs, 1)

    return predicts.data.numpy()

class MyPlotter():
    def __init__(self, model, X, Y, n_epoch, filepath=None, h = .01):
        self.model = model
        self.X = X
        self.Y = Y
        self.n_epoch = n_epoch
        self.filepath = filepath
        x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
        y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
        self.xx, self.yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        self.loss_hist = []
        self.val_loss_hist = []
        self.X_grid = np.c_[self.xx.ravel(), self.yy.ravel()]

        #Gráficos a serem mostrados pelo callback
        self.fig = plt.figure(figsize=(12, 4), dpi=100)
        self.ax1 = self.fig.add_subplot(1, 3, 1)
        self.ax1.set_xlim(0, nb_epoch)
        self.ax1.set_xlabel('Epoca')#,fontsize=28)
        self.ax1.set_ylabel('Perda')#,fontsize=28)
        self.ax1.set_title('Perda x Época')
        self.ax1.plot([],[],'b',linewidth = 2.0,label = "Treino")
        self.ax1.grid(True)

        self.ax2 = self.fig.add_subplot(1, 3, 2)
        self.ax2.set_xlim(Xc[:,0].min(), Xc[:,0].max())
        self.ax2.set_ylim(Xc[:,1].min(), Xc[:,1].max())
        self.ax2.set_xlabel('Comprimento da Sepala')#,fontsize=28)
        self.ax2.set_ylabel('Largura da Sepala')#,fontsize=28)
        self.ax2.set_title('Fronteiras de decisão')

        self.ax3 = self.fig.add_subplot(1, 3, 3)
        self.ax3.set_xlim(Xc[:,0].min(), Xc[:,0].max())
        self.ax3.set_ylim(Xc[:,1].min(), Xc[:,1].max())
        self.ax3.set_xlabel('Comprimento da Sepala')#,fontsize=28)
        self.ax3.set_ylabel('Largura da Sepala')#,fontsize=28)
        self.ax3.set_title('Máxima probabilidade')

    def on_train_begin(self, logs={}):
        display.display(self.fig)
        display.clear_output(wait=True)

    def on_epoch_end(self, epoch, logs={}):
        if 'loss' in logs.keys():
            self.loss_hist.append(logs['loss'])

            if epoch%250==0:
                self.ax1.plot(np.arange(epoch+1), self.loss_hist, 'b', linewidth = 2.0)

                #Z = predict(self.model, torch.from_numpy(self.X_grid).type(torch.FloatTensor))
                Zc = predict(self.model,torch.FloatTensor(self.X_grid))
                Zc = Zc.reshape(self.xx.shape)

                self.ax2.pcolormesh(self.xx, self.yy, Zc, cmap=plt.cm.Paired)
                colors = np.array(['r','y','b'])
                self.ax2.scatter(self.X[:, 0], self.X[:, 1], s=40, c=colors[self.Y], edgecolors='k', cmap=plt.cm.Paired)

                Zp = predict_prob(self.model,torch.FloatTensor(self.X_grid))
                Zp = Zp.reshape(self.xx.shape)

                self.ax3.pcolormesh(self.xx, self.yy, Zp, cmap=plt.cm.magma)
                colors = np.array(['r','y','b'])
                self.ax3.scatter(self.X[:, 0], self.X[:, 1], s=40, c=colors[self.Y], edgecolors='k', cmap=plt.cm.Paired)

                display.display(self.fig)
                display.clear_output(wait=True)

# %% [markdown]
# ### Laço principal de treinamento da Regressão Logística por Softmax

# %%
lr = 0.15

optimizer = torch.optim.SGD(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# %%
nb_epoch = 10000

losses = []
losses_test = []
acc_list = []
acc_test_list = []
for i in range(nb_epoch):
    # predict da rede
    output = model(X_train_tensor)
    output_test = model(X_test_tensor)

    # calcula a perda
    loss = criterion(output, Y_train_tensor)
    loss_test = criterion(output_test, Y_test_tensor)

    # Faz o backpropagation para calcular os gradientes e otimizar parâmetros
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    losses.append(loss.data.item())
    losses_test.append(loss_test.data.item())

    _, class_max = torch.max(F.softmax(output,dim=1),dim=1)
    _, class_test_max = torch.max(F.softmax(output_test,dim=1),dim=1)
    acc_list.append((class_max == Y_train_tensor).float().mean())
    acc_test_list.append((class_test_max == Y_test_tensor).float().mean())

    final_loss = loss.data.item()

print('Final loss:', final_loss)
# Out:
# Final loss: 0.2060997039079666

# %%
print(acc_list)
# Out:
# [tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3333), tensor(0.3417), tensor(0.3583), tensor(0.3917), tensor(0.4167), tensor(0.4583), tensor(0.5250), tensor(0.5917), tensor(0.6333), tensor(0.6417), tensor(0.6583), tensor(0.7000), tensor(0.6833), tensor(0.6333), tensor(0.6250), tensor(0.6167), tensor(0.6083), tensor(0.6000), tensor(0.6000), tensor(0.6000), tensor(0.6083), tensor(0.6083), tensor(0.6083), tensor(0.6167), tensor(0.6167), tensor(0.6167), tensor(0.6167), tensor(0.6333), tensor(0.6333), tensor(0.6333), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6417), tensor(0.6500), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6583), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6667), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6750), tensor(0.6833), tensor(0.6833), tensor(0.6833), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.6917), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7083), tensor(0.7167), tensor(0.7167), tensor(0.7167), tensor(0.7250), tensor(0.7250), tensor(0.7250), tensor(0.7250), tensor(0.7250), tensor(0.7250), tensor(0.7250), tensor(0.7333), tensor(0.7333), tensor(0.7333), tensor(0.7333), tensor(0.7333), tensor(0.7250), tensor(0.7250), tensor(0.7333), tensor(0.7417), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7500), tensor(0.7667), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7750), tensor(0.7833), tensor(0.7833), tensor(0.7833), tensor(0.7833), tensor(0.7833), tensor(0.7833), tensor(0.7833), tensor(0.7917), tensor(0.7917), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8000), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8083), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), tensor(0.8167), ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(list(range(nb_epoch)), losses, label='Treino')
plt.plot(list(range(nb_epoch)), losses_test, label='Validação')
plt.xlabel('Época')
plt.ylabel('Perda')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(list(range(nb_epoch)), acc_list, label='Treino')
plt.plot(list(range(nb_epoch)), acc_test_list, label='Teste')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.legend()
plt.show()

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Parâmetros após treinamento

# %%
model.state_dict()
# Out:
# OrderedDict([('weight',
#               tensor([[ -3.5035, -14.7081],
#                       [  1.5903,  -0.7756],
#                       [  1.1210,  15.2286]])),
#              ('bias', tensor([ 6.9114,  1.4777, -8.7725]))])

# %% [markdown]
# ### Salvando os parâmetros treinados

# %%
os.makedirs('../models',exist_ok=True)
torch.save(model.state_dict(),'../models/RegrLog_Iris.pt')

# %%
! ls ../models/
# Out:
# RegrLog_Iris.pt

# %%
nn.init.constant(model.weight,0)
model.state_dict()
# Out:
# /tmp/ipython-input-952960416.py:1: FutureWarning: `nn.init.constant` is now deprecated in favor of `nn.init.constant_`.
#   nn.init.constant(model.weight,0)
# OrderedDict([('weight',
#               tensor([[0., 0.],
#                       [0., 0.],
#                       [0., 0.]])),
#              ('bias', tensor([ 6.9114,  1.4777, -8.7725]))])

# %% [markdown]
# ### Recuperando os pesos salvos

# %%
param_saved = torch.load('../models/RegrLog_Iris.pt')
model.load_state_dict(param_saved)
model.state_dict()
# Out:
# OrderedDict([('weight',
#               tensor([[ -3.5035, -14.7081],
#                       [  1.5903,  -0.7756],
#                       [  1.1210,  15.2286]])),
#              ('bias', tensor([ 6.9114,  1.4777, -8.7725]))])

# %% [markdown]
# ### Exatidão (acurácia) do classificador

# %% [markdown]
# Acurácia indica o número de acertos sobre o número total de amostras

# %%
Y_pred = predict(model, X_tensor)
accuracy = (Y_pred == Y).mean()
print('Training Accuracy: ', accuracy)
# Out:
# Training Accuracy:  0.96

# %% [markdown]
# ### Matriz de confusão

# %%
import pandas as pd
pd.crosstab(Y_pred, Y)
# Out:
# col_0   0   1   2
# row_0
# 0      50   0   0
# 1       0  47   3
# 2       0   3  47

# %% [markdown]
# ## Atividades

# %% [markdown]
# ### Perguntas:

# %% [markdown]
# 1. Observe que se após o treinamento, a célula for executada novamente, ela continua utilizando os parâmetros treinados até sua última execução. O que é preciso fazer para que o treinamento comece deste o início, como da primeira vez que foi executado?
#
# 2. Experimente refazer o treinamento com diferentes valores de learning rate

# %% [markdown]
# ### Exercícios:

# %% [markdown]
# 1. Observando o gráfico de máxima probabilidade, responda:
#     1. Qual é a amostra classificada corretamente, com maior probabilidade?
#
#     2. Qual é a amostra classificada erradamente, com maior probabilidade?
#
#     3. Qual é a amostra classificada corretamente, com menor probabilidade?
#     4. Qual é a amostra classificada erradamente, com menor probabilidade?
# 2. Quantos parâmetros possui esta rede? Quantos são da camada densa e quantos são de bias?
# 3. Quantas entradas e quantas saídas esta rede possui?
# 4. Como se pode calcular a acurácia a partir da matriz de confusão?
# 5. O que faz a função `torch.max`? Quantos parâmetros ela retorna e quais seus significados?
#     - http://pytorch.org/docs/master/torch.html?highlight=torch%20max#torch.max

# %% [markdown]
# ## Principais aprendizados
